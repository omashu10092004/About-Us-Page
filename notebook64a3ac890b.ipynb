ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
#
# 0        4.3   NaN  128          NaN           48         13           4000
#
# 1        3.4   6.0   64         4.50           48         12           4000
#
# 2        4.3   4.0    4         4.50           64         16           4000
#
# 3        4.4   6.0   64         6.40           48         15           3800
#
# 4        4.5   6.0  128         6.18           35         15           3800
#
# ..       ...   ...  ...          ...          ...        ...            ...
#
# 802      3.8   6.0   32         4.54           48         12           2800
#
# 803      4.1   8.0   64         4.54           64          8           2500
#
# 804      4.4   3.0   32         6.20           48          1           3800
#
# 805      3.7  10.0   32         4.50           64          8           3500
#
# 806      3.5   6.0   32         4.50           64         15           1050
#
#
#
#      Price
#
# 0    24999
#
# ...

# %%
x=df['Battery_Power']
y=df['Price']
print(x)
# Out:
# 0      4000
#
# 1      4000
#
# 2      4000
#
# 3      3800
#
# 4      3800
#
#        ...
#
# 802    2800
#
# 803    2500
#
# 804    3800
#
# 805    3500
#
# 806    1050
#
# Name: Battery_Power, Length: 807, dtype: int64

# %%
print(y)
# Out:
# 0      24999
#
# 1      15999
#
# 2      15000
#
# 3      18999
#
# 4      18999
#
#        ...
#
# 802     1299
#
# 803     1390
#
# 804     9790
#
# 805      799
#
# 806      799
#
# Name: Price, Length: 807, dtype: int64

# %%
plt.scatter(df['Ratings'],df['Price'],color='red')
plt.xlabel("Battery_Power")
plt.ylabel("Primary_Cam")
plt.title("Mobile_Size")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=0)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (645,)
#
# x_test: (162,)
#
# y_train: (645,)
#
# y_test: (162,)

# %%
x_train=np.array(x_train)
y_train-np.array(y_train)
x_test-np.array(x_test)
print(x_test)
# Out:
# 312    3000
#
# 389    3500
#
# 196    3000
#
# 14     3800
#
# 401    3000
#
#        ...
#
# 49     3500
#
# 258    4230
#
# 793    3800
#
# 116    3000
#
# 37     1200
#
# Name: Battery_Power, Length: 162, dtype: int64

# %%
print(y_test)
# Out:
# 312     3999
#
# 389    36999
#
# 196      715
#
# 14     43999
#
# 401      995
#
#        ...
#
# 49     53990
#
# 258     9990
#
# 793    18999
#
# 116      639
#
# 37       945
#
# Name: Price, Length: 162, dtype: int64

# %%
import numpy as np
x_train = x_train.reshape(-1, 1)
y_train = y_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)
print(x_test)
# Out:
# [[3000]
#
#  [3500]
#
#  [3000]
#
#  [3800]
#
#  [3000]
#
#  [3000]
#
#  [3000]
#
#  [3000]
#
#  [3800]
#
#  [3000]
#
#  [4020]
#
#  [4025]
#
#  [3800]
#
#  [3500]
#
#  [5000]
#
#  [3800]
#
#  [3800]
#
#  [3800]
#
#  [3500]
#
#  [4085]
#
#  [3000]
#
#  [3000]
#
#  [4700]
#
#  [4700]
#
#  [5000]
#
#  [1050]
#
#  [5000]
#
#  [3000]
#
#  [3000]
#
#  [1750]
#
#  [4700]
#
#  [4030]
#
#  [3350]
#
#  [4700]
#
#  [3800]
#
#  [3500]
#
#  [5000]
#
#  [3000]
#
#  [3500]
#
#  [3000]
#
#  [3400]
#
#  [3500]
#
#  [4100]
#
#  [3500]
#
#  [4200]
#
#  [1050]
#
#  [3800]
#
#  [2800]
#
#  [3500]
#
#  [3000]
#
#  [3000]
#
#  [3800]
#
#  [4700]
#
#  [3000]
#
#  [3000]
#
#  [5000]
#
#  [3600]
#
#  [1200]
#
#  [3500]
#
#  [3000]
#
#  [3800]
#
#  [3000]
#
#  [3800]
#
#  [3000]
#
#  [1900]
#
#  [3500]
#
#  [3500]
#
#  [1200]
#
#  [6000]
#
#  [3000]
#
#  [3000]
#
#  [6000]
#
#  [3000]
#
#  [3800]
#
#  [3000]
#
#  [3000]
#
#  [1200]
#
#  [3000]
#
#  [1200]
#
#  [3500]
#
#  [2500]
#
#  [3500]
#
#  [4000]
#
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression() 
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
print("The coefficient:", lr.coef_) 
print("intercept", lr.intercept_)
# Out:
# The coefficient: [[8.86863801]]
#
# intercept [-15410.17055977]

# %%
y_pred=lr.predict(x_test)

# %%
print(y_pred)
# Out:
# [[11195.74347274]
#
#  [15630.06247816]
#
#  [11195.74347274]
#
#  [18290.65388141]
#
#  [11195.74347274]
#
#  [11195.74347274]
#
#  [11195.74347274]
#
#  [11195.74347274]
#
#  [18290.65388141]
#
#  [11195.74347274]
#
#  [20241.7542438 ]
#
#  [20286.09743385]
#
#  [18290.65388141]
#
#  [15630.06247816]
#
#  [28933.01949442]
#
#  [18290.65388141]
#
#  [18290.65388141]
#
#  [18290.65388141]
#
#  [15630.06247816]
#
#  [20818.2157145 ]
#
#  [11195.74347274]
#
#  [11195.74347274]
#
#  [26272.42809117]
#
#  [26272.42809117]
#
#  [28933.01949442]
#
#  [-6098.10064839]
#
#  [28933.01949442]
#
#  [11195.74347274]
#
#  [11195.74347274]
#
#  [  109.9459592 ]
#
#  [26272.42809117]
#
#  [20330.44062391]
#
#  [14299.76677654]
#
#  [26272.42809117]
#
#  [18290.65388141]
#
#  [15630.06247816]
#
#  [28933.01949442]
#
#  [11195.74347274]
#
#  [15630.06247816]
#
#  [11195.74347274]
#
#  [14743.19867708]
#
#  [15630.06247816]
#
#  [20951.24528466]
#
#  [15630.06247816]
#
#  [21838.10908575]
#
# ...

# %%
plt.scatter(x_test, y_test,color='blue')
plt.plot(x_test, y_pred,color='red')
plt.xlabel("RAM")
plt.ylabel("ROM")
plt.show()

# %%
from sklearn import metrics
MSE=metrics.mean_squared_error(y_test,y_pred)
print("MSE:",MSE)
RMSE=np.sqrt(MSE) 
print("RMSE:", RMSE)
MAE=metrics.mean_absolute_error(y_test,y_pred)
print("MAE:", MAE)
r2_square=metrics.r2_score(y_test,y_pred)
print("Accuracy:",r2_square)
# Out:
# MSE: 568017844.6364062
#
# RMSE: 23833.12494484108
#
# MAE: 14806.143729262049
#
# Accuracy: 0.13363227864105576

# %%
y_new=[98273.0]
x_new=np.array([[7.1]])
prediction=lr.predict(x_new)
print("Actual:{0} and Predicted:{1}".format(y_new,prediction[0]))
# Out:
# Actual:[98273.0] and Predicted:[-15347.20322989]
